# %% [markdown]
# Q1 > who developed the python language?
#
# >> Guido van Rossum
#
# Q2 > which type of programming does python support?
#
# >> OOP, Structured, Functional
#
# Q3 > is python case sensitive when dealing with identifier?
#
# >> Yes
#
# Q4 > what is the correct extension of the python file?
#
# >> .py
#
# Q5 > is python code interpreted or compiled?
#
# >> python code is both interpreted and compiled
#
# Q6 > name a few blocks of code used to define in python language
#
# >> a module, a function body, and a class definition
#
# Q7 > state character used to give single line comment in python
#
# >> #
#
# Q8 > name the function which gives us current version of python
#
# >> sys.version
#
# Q9 > python supports the creation of anonymous functions at runtime using a construct called
#
# >> lambda
#
# Q10 > what does pip stand for python
#
# >> pip Install Packages
#
# Q11 > mention a few built-in functions in python
#
# >> sum, list, bool, eval, dict, format, float, pow, etc.
#
# Q12 > what is the maximum possible length of a python identifier
#
# >> 79 characters
#
# Q13 > What are the benifits of using python
#
# >> we can do OOP, functional and scripting in python. Python has easy syntax and already created tons of inbuilt fuctions, libraries and modules which we can use directly by importing them, so vastly used in Data Science domain
#
# Q14 > how is memory managed in python
#
# >> Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager.
#
# Q15 > How to install python on windows and set path variables
#
# >> We can download python from its offical website. Later by running the exe it gets install and we need to check the add path variable check box
#
# Q16 > Is indentation requiered in python
#
# >> Yes
